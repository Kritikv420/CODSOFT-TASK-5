# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LogisticRegression as LogReg
from sklearn.metrics import accuracy_score as acc_score

# %%
cc_data = pd.read_csv('/content/creditcard.csv')

# %%
cc_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
cc_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 71391  54278  1.039072 -0.213656  0.431251  0.918611 -0.621456 -0.667224
# 71392  54279 -5.084290 -4.002881  1.329865 -0.573442 -0.690674  0.019033
# 71393  54280  1.441869 -0.411978 -0.357381 -0.981390 -0.244335 -0.292055
# 71394  54280 -0.441533  0.363429  1.434158 -2.116500 -0.582532 -1.354317
# 71395  54281  1.236141  0.256586  0.175963  0.504282 -0.197600 -0.569588
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 71391  0.134553 -0.181427  0.400214  ... -0.167499 -0.510090 -0.079011
# 71392  0.844001 -0.466913  0.381563  ... -0.962575  0.808686  2.249283
# 71393 -0.242842 -0.091250 -1.241760  ... -0.832744 -2.041536  0.134713
# 71394  0.886887 -0.335278  0.949012  ... -0.028278  0.146103 -0.101250
# 71395 -0.058326 -0.005874 -0.125664  ... -0.263713 -0.821591  0.081703
#
#             V24       V25       V26       V27       V28  Amount  Class
# 71391  0.444677  0.428995  0.256921 -0.039011  0.031128  106.85    0.0
# 71392  0.165161  1.093631 -0.235500 -0.055029 -0.272360  314.31    0.0
# 71393 -0.883851  0.100577  0.680045 -0.083669 -0.013649   11.97    0.0
# 71394  0.781919  0.258258 -0.843708  0.155215  0.121668   57.01    0.0
# 71395 -0.056701  0.212892       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
cc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71396 entries, 0 to 71395
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    71396 non-null  int64
#  1   V1      71396 non-null  float64
#  2   V2      71396 non-null  float64
#  3   V3      71396 non-null  float64
#  4   V4      71396 non-null  float64
#  5   V5      71396 non-null  float64
#  6   V6      71396 non-null  float64
#  7   V7      71396 non-null  float64
#  8   V8      71396 non-null  float64
#  9   V9      71396 non-null  float64
#  10  V10     71396 non-null  float64
#  11  V11     71396 non-null  float64
#  12  V12     71396 non-null  float64
#  13  V13     71396 non-null  float64
#  14  V14     71396 non-null  float64
#  15  V15     71396 non-null  float64
#  16  V16     71396 non-null  float64
#  17  V17     71396 non-null  float64
#  18  V18     71396 non-null  float64
#  19  V19     71396 non-null  float64
#  20  V20     71396 non-null  float64
#  21  V21     71396 non-null  float64
#  22  V22     71396 non-null  float64
#  23  V23     71396 non-null  float64
#  24  V24     71396 non-null  float64
#  25  V25     71396 non-null  float64
#  26  V26     71395 non-null  float64
#  27  V27     71395 non-null  float64
#  28  V28     71395 non-null  float64
#  29  Amount  71395 non-null  float64
#  30  Class   71395 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 16.9 MB

# %%
cc_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
cc_data['Class'].value_counts()
# Out:
# Class
# 0.0    71218
# 1.0      177
# Name: count, dtype: int64

# %%
legit_transactions = cc_data[cc_data['Class'] == 0]
fraud_transactions = cc_data[cc_data['Class'] == 1]

# %%
print(legit_transactions.shape)
print(fraud_transactions.shape)
# Out:
# (71218, 31)
# (177, 31)

# %%
legit_transactions['Amount'].describe()
# Out:
# count    71218.000000
# mean        97.028781
# std        270.410639
# min          0.000000
# 25%          7.680000
# 50%         26.550000
# 75%         88.500000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud_transactions['Amount'].describe()
# Out:
# count     177.000000
# mean       95.719153
# std       219.167165
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
cc_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    35066.440352 -0.234234 -0.036579  0.704647  0.155872 -0.259090
# 1.0    30570.542373 -6.805243  4.918403 -9.162545  5.314564 -5.079731
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105218 -0.097289  0.048430  0.023374  ...  0.044548 -0.031241
# 1.0   -2.088712 -7.147266  3.352192 -3.180791  ...  0.426844  0.822681
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106249 -0.038231  0.006499  0.135292  0.022316  0.001788  0.002561
# 1.0   -0.189293 -0.245318 -0.073800  0.248813  0.105956  0.564291  0.045180
#
#           Amount
# Class
# 0.0    97.028781
# 1.0    95.719153
#
# [2 rows x 30 columns]

# %%
sampled_legit = legit_transactions.sample(n=492)

# %%
combined_dataset = pd.concat([sampled_legit, fraud_transactions], axis=0)

# %%
combined_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 4464    3771  1.407921 -0.324243  0.711125 -0.463927 -1.044828 -0.995387
# 50270  44417 -0.978247 -0.314510  0.863641 -2.470813  0.819142 -1.384657
# 39186  39730  1.263057  0.312533  0.046507  0.412040  0.053592 -0.346345
# 27241  34457  0.305209  1.556493 -2.426500  1.595300  0.504916 -1.301325
# 35929  38323  1.316063  0.500361 -0.333874  0.979344  0.312297 -0.883284
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 4464  -0.640606 -0.273204  0.514909  ... -0.245992 -0.587763  0.146154
# 50270  0.558427 -0.170404  0.642473  ...  0.185467  0.313783 -0.175310
# 39186 -0.007607 -0.032577 -0.233425  ... -0.277387 -0.814996  0.028054
# 27241  0.712186  0.352720 -0.602221  ... -0.037855 -0.232146  0.304873
# 35929  0.550327 -0.329898 -0.265245  ... -0.030948 -0.019346 -0.212970
#
#             V24       V25       V26       V27       V28  Amount  Class
# 4464   0.304105  0.205932 -0.519895 -0.017076  0.016413   10.00    0.0
# 50270 -0.390018  0.381962  0.010839  0.024048  0.111248   55.71    0.0
# 39186 -0.387591  0.289939  0.118492 -0.025392  0.014339    1.29    0.0
# 27241 -0.393983 -0.427363 -0.394102  0.089182 -0.056979   89.99    0.0
# 35929 -0.127754  0.929770 -0.263575 -0.007514  0.005739    1.00    0.0
#
# [5 rows x 31 columns]

# %%
combined_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 68633  53076  1.296231  0.417447  0.193963  0.901644  0.130531 -0.371634
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 68633  0.158126 -0.202669 -0.079512  ... -0.112114 -0.220002 -0.121022
# 69498 -2.582865  0.643230 -1.191233  ...  0.594623  0.372144 -0.310456
# 69980 -2.340991  0.713004 -1.416265  ...  0.383180 -0.213952 -0.336640
# 70141 -2.355254  0.854659 -1.281243  ...  0.679176  0.731907  0.333045
# 70589 -3.039520 -1.634233 -0.594809  ... -0.723326  0.501222 -0.696892
#
#             V24       V25       V26       V27       V28  Amount  Class
# 68633 -0.440454  0.671540 -0.413518  0.032838  0.020600    1.18    1.0
# 69498 -0.624065  0.840216 -0.159452  0.599482  0.288916    8.00    1.0
# 69980  0.237076  0.246003 -0.044228  0.510729  0.220952    0.00    1.0
# 70141  0.392505 -0.274197  0.802349  0.390809  0.112146  112.45    1.0
# 70589 -0.600514  0.127547 -0.786072  0.606097  0.171697  261.87    1.0
#
# [5 rows x 31 columns]

# %%
combined_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    177
# Name: count, dtype: int64

# %%
combined_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    36464.973577 -0.153882 -0.079521  0.720711  0.072943 -0.309981
# 1.0    30570.542373 -6.805243  4.918403 -9.162545  5.314564 -5.079731
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.129653 -0.035303  0.049951 -0.000330  ...  0.067285  0.033620
# 1.0   -2.088712 -7.147266  3.352192 -3.180791  ...  0.426844  0.822681
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.124861 -0.021727  0.01661  0.115772  0.047668 -0.006431  0.000741
# 1.0   -0.189293 -0.245318 -0.07380  0.248813  0.105956  0.564291  0.045180
#
#            Amount
# Class
# 0.0    109.362053
# 1.0     95.719153
#
# [2 rows x 30 columns]

# %%
X = combined_dataset.drop(columns='Class', axis=1)
y = combined_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 4464    3771  1.407921 -0.324243  0.711125 -0.463927 -1.044828 -0.995387
# 50270  44417 -0.978247 -0.314510  0.863641 -2.470813  0.819142 -1.384657
# 39186  39730  1.263057  0.312533  0.046507  0.412040  0.053592 -0.346345
# 27241  34457  0.305209  1.556493 -2.426500  1.595300  0.504916 -1.301325
# 35929  38323  1.316063  0.500361 -0.333874  0.979344  0.312297 -0.883284
# ...      ...       ...       ...       ...       ...       ...       ...
# 68633  53076  1.296231  0.417447  0.193963  0.901644  0.130531 -0.371634
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 4464  -0.640606 -0.273204  0.514909  ...  0.025373 -0.245992 -0.587763
# 50270  0.558427 -0.170404  0.642473  ...  0.234078  0.185467  0.313783
# 39186 -0.007607 -0.032577 -0.233425  ... -0.025772 -0.277387 -0.814996
# 27241  0.712186  0.352720 -0.602221  ...  0.121271 -0.037855 -0.232146
# 35929  0.550327 -0.329898 -0.265245  ... -0.129132 -0.030948 -0.019346
# ...         ...       ...       ...  ...       ...       ...       ...
# 68633  0.158126 -0.202669 -0.079512  ... -0.029559 -0.112114 -0.220002
# 69498 -2.582865  0.643230 -1.191233  ...  0.380545  0.594623  0.372144
# 69980 -2.340991  0.713004 -1.416265  ...  0.002749  0.383180 -0.213952
# 70141 -2.355254  0.854659 -1.281243  ...  0.087406  0.679176  0.731907
# 70589 -3.039520 -1.634233 -0.594809  ...  0.825566 -0.723326  0.501222
#
#             V23       V24       V25       V26       V27       V28  Amount
# 4464   0.146154  0.304105  0.205932 -0.519895 -0.017076  0.016413   10.00
# 50270 -0.175310 -0.390018  0.381962  0.010839  0.024048  0.111248   55.71
# 39186  0.028054 -0.387591  0.289939  0.118492 -0.025392  0.014339    1.29
# 27241  0.304873 -0.393983 -0.427363 -0.394102  0.089182 -0.056979   89.99
# 35929 -0.212970 -0.127754  0.929770 -0.263575 -0.007514  0.005739    1.00
# ...         ...       ...       ...       ...       ...       ...     ...
# 68633 -0.121022 -0.440454  0.671540 -0.413518  0.032838  0.020600    1.18
# 69498 -0.310456 -0.624065  0.840216 -0.159452  0.599482  0.288916    8.00
# 69980 -0.336640  0.237076  0.246003 -0.044228  0.510729  0.220952    0.00
# 70141  0.333045  0.392505 -0.274197  0.802349  0.390809  0.112146  112.45
# 70589 -0.696892 -0.600514  0.127547 -0.786072  0.606097  0.171697  261.87
#
# [669 rows x 30 columns]

# %%
print(y)
# Out:
# 4464     0.0
# 50270    0.0
# 39186    0.0
# 27241    0.0
# 35929    0.0
#         ...
# 68633    1.0
# 69498    1.0
# 69980    1.0
# 70141    1.0
# 70589    1.0
# Name: Class, Length: 669, dtype: float64

# %%
X_train, X_test, y_train, y_test = tts(X, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (669, 30) (535, 30) (134, 30)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, y_train) # Changed Y_train to y_train

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9757009345794393

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test) # Changed Y_test to y_test

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9626865671641791
